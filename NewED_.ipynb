# %%
import pandas as pd
import numpy as np

# %%
van19 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan19.csv')
van19 = van19.rename(columns = {'Label (Grouping)':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
print (van19)
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:   43,850  ±3,518
# 1                             Science and Engineering      NaN     NaN
# 2               Computers, Mathematics and Statistics    2,812    ±927
# 3           Biological, Agricultural, and Environm...    2,517    ±736
# 4                       Physical and Related Sciences    1,398    ±697
# 5                                          Psychology    3,021    ±919
# 6                                     Social Sciences    3,513    ±885
# 7                                         Engineering    3,609    ±833
# 8                           Multidisciplinary Studies      122    ±141
# 9              Science and Engineering Related Fields    4,608  ±1,321
# 10                                           Business    5,981  ±1,125
# 11                                          Education    4,528  ±1,059
# ...

# %%
van19 = van19.dropna()
van19
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:   43,850  ±3,518
# 2               Computers, Mathematics and Statistics    2,812    ±927
# 3           Biological, Agricultural, and Environm...    2,517    ±736
# 4                       Physical and Related Sciences    1,398    ±697
# 5                                          Psychology    3,021    ±919
# 6                                     Social Sciences    3,513    ±885
# 7                                         Engineering    3,609    ±833
# 8                           Multidisciplinary Studies      122    ±141
# 9              Science and Engineering Related Fields    4,608  ±1,321
# 10                                           Business    5,981  ±1,125
# 11                                          Education    4,528  ±1,059
# 13                           Literature and Languages    2,243    ±694
# ...

# %%
por19 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor19.csv')
por19 = por19.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por19 = por19.dropna()
por19
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  286,626  ±8,011
# 2               Computers, Mathematics and Statistics   11,752  ±1,806
# 3           Biological, Agricultural, and Environm...   24,327  ±2,307
# 4                       Physical and Related Sciences   13,213  ±2,239
# 5                                          Psychology   16,446  ±2,231
# 6                                     Social Sciences   35,169  ±3,060
# 7                                         Engineering   15,281  ±2,126
# 8                           Multidisciplinary Studies    3,965  ±1,021
# 9              Science and Engineering Related Fields   22,976  ±2,727
# 10                                           Business   32,875  ±3,056
# 11                                          Education   16,783  ±2,072
# 13                           Literature and Languages   24,181  ±2,950
# ...

# %%
van18 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan18.csv')
van18 = van18.rename(columns = {'Label (Grouping':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van18 = van18.dropna()
van18
# Out:
#                                      Label (Grouping) Estimate      ME
# 0                                              Total:   43,670  ±3,119
# 2               Computers, Mathematics and Statistics    1,470    ±640
# 3           Biological, Agricultural, and Environm...    2,554    ±764
# 4                       Physical and Related Sciences      918    ±408
# 5                                          Psychology    2,954    ±826
# 6                                     Social Sciences    4,240  ±1,072
# 7                                         Engineering    2,885    ±864
# 8                           Multidisciplinary Studies      727    ±391
# 9              Science and Engineering Related Fields    3,239    ±732
# 10                                           Business    8,133  ±1,391
# 11                                          Education    4,541  ±1,161
# 13                           Literature and Languages    2,446    ±793
# ...

# %%
por18 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor18.csv')
por18 = por18.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por18 = por18.dropna()
por18
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  273,786  ±7,450
# 2               Computers, Mathematics and Statistics   10,094  ±1,968
# 3           Biological, Agricultural, and Environm...   21,612  ±2,279
# 4                       Physical and Related Sciences   10,766  ±1,718
# 5                                          Psychology   13,557  ±1,640
# 6                                     Social Sciences   33,285  ±2,531
# 7                                         Engineering   13,617  ±1,367
# 8                           Multidisciplinary Studies    3,267    ±817
# 9              Science and Engineering Related Fields   20,121  ±2,312
# 10                                           Business   35,895  ±3,325
# 11                                          Education   14,312  ±1,690
# 13                           Literature and Languages   26,894  ±2,582
# ...

# %%
van17 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan17.csv')
van17 = van17.rename(columns = {'Label (Grouping':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van17 = van17.dropna()
van17
# Out:
#                                      Label (Grouping) Estimate      ME
# 0                                              Total:   37,759  ±3,444
# 2               Computers, Mathematics and Statistics    1,462    ±694
# 3           Biological, Agricultural, and Environm...    2,720    ±704
# 4                       Physical and Related Sciences      491    ±273
# 5                                          Psychology    2,348    ±588
# 6                                     Social Sciences    3,307    ±850
# 7                                         Engineering    3,252  ±1,005
# 8                           Multidisciplinary Studies      337    ±275
# 9              Science and Engineering Related Fields    3,375    ±852
# 10                                           Business    6,714  ±1,469
# 11                                          Education    3,824    ±807
# 13                           Literature and Languages    2,087    ±595
# ...

# %%
por17 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor17.csv')
por17 = por17.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por17 = por17.dropna()
por17
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  266,000  ±8,528
# 2               Computers, Mathematics and Statistics    9,298  ±1,265
# 3           Biological, Agricultural, and Environm...   19,470  ±2,147
# 4                       Physical and Related Sciences    9,837  ±1,564
# 5                                          Psychology   16,795  ±2,254
# 6                                     Social Sciences   35,498  ±2,923
# 7                                         Engineering   13,650  ±1,762
# 8                           Multidisciplinary Studies    2,981    ±836
# 9              Science and Engineering Related Fields   21,383  ±2,286
# 10                                           Business   32,058  ±2,916
# 11                                          Education   14,751  ±1,840
# 13                           Literature and Languages   22,600  ±2,378
# ...

# %%
van16 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan16.csv')
van16 = van16.rename(columns = {'Label (Grouping':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van16 = van16.dropna()
van16
# Out:
#                                      Label (Grouping) Estimate      ME
# 0                                              Total:   35,774  ±3,053
# 2               Computers, Mathematics and Statistics    1,155    ±392
# 3           Biological, Agricultural, and Environm...    2,646    ±976
# 4                       Physical and Related Sciences    1,733    ±691
# 5                                          Psychology    1,244    ±448
# 6                                     Social Sciences    3,867    ±880
# 7                                         Engineering    2,409    ±646
# 8                           Multidisciplinary Studies      302    ±235
# 9              Science and Engineering Related Fields    2,890    ±726
# 10                                           Business    6,957  ±1,211
# 11                                          Education    3,094    ±757
# 13                           Literature and Languages    1,748    ±648
# ...

# %%
por16 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor16.csv')
por16 = por16.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por16 = por16.dropna()
por16
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  259,541  ±7,746
# 2               Computers, Mathematics and Statistics    8,088  ±1,106
# 3           Biological, Agricultural, and Environm...   19,855  ±2,176
# 4                       Physical and Related Sciences    9,655  ±1,453
# 5                                          Psychology   15,929  ±1,790
# 6                                     Social Sciences   35,076  ±2,753
# 7                                         Engineering   13,651  ±1,603
# 8                           Multidisciplinary Studies    2,981    ±869
# 9              Science and Engineering Related Fields   17,889  ±2,015
# 10                                           Business   29,224  ±3,459
# 11                                          Education   15,576  ±1,629
# 13                           Literature and Languages   23,870  ±2,078
# ...

# %%
por15 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor15.csv')
por15 = por15.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por15 = por15.dropna()
por15
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  250,228  ±6,860
# 2               Computers, Mathematics and Statistics    9,592  ±1,405
# 3           Biological, Agricultural, and Environm...   19,845  ±2,047
# 4                       Physical and Related Sciences    8,235  ±1,379
# 5                                          Psychology   13,401  ±1,598
# 6                                     Social Sciences   28,442  ±2,395
# 7                                         Engineering   12,695  ±1,768
# 8                           Multidisciplinary Studies    3,354    ±785
# 9              Science and Engineering Related Fields   20,813  ±2,040
# 10                                           Business   28,247  ±2,275
# 11                                          Education   15,426  ±2,114
# 13                           Literature and Languages   25,139  ±2,195
# ...

# %%
por14 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor14.csv')
por14 = por14.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por14 = por14.dropna()
por14
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  228,443  ±7,239
# 2               Computers, Mathematics and Statistics    7,019  ±1,077
# 3           Biological, Agricultural, and Environm...   17,530  ±1,779
# 4                       Physical and Related Sciences    8,300  ±1,443
# 5                                          Psychology   15,197  ±1,938
# 6                                     Social Sciences   33,021  ±2,806
# 7                                         Engineering   11,364  ±1,463
# 8                           Multidisciplinary Studies    2,443    ±702
# 9              Science and Engineering Related Fields   15,632  ±1,942
# 10                                           Business   24,703  ±2,772
# 11                                          Education   13,304  ±1,551
# 13                           Literature and Languages   17,884  ±1,895
# ...

# %%
por13 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor13.csv')
por13 = por13.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por13 = por13.dropna()
por13
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  228,288  ±7,428
# 2               Computers, Mathematics and Statistics    6,183  ±1,226
# 3           Biological, Agricultural, and Environm...   17,120  ±2,345
# 4                       Physical and Related Sciences    7,015  ±1,403
# 5                                          Psychology   12,266  ±1,605
# 6                                     Social Sciences   30,336  ±2,719
# 7                                         Engineering   13,665  ±1,856
# 8                           Multidisciplinary Studies    3,233  ±1,360
# 9              Science and Engineering Related Fields   19,779  ±1,947
# 10                                           Business   28,466  ±3,235
# 11                                          Education   14,626  ±1,640
# 13                           Literature and Languages   19,985  ±2,066
# ...

# %%
por12 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor12.csv')
por12 = por12.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por12 = por12.dropna()
por12
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  218,014  ±6,916
# 2               Computers, Mathematics and Statistics    7,338  ±1,231
# 3           Biological, Agricultural, and Environm...   13,716  ±1,935
# 4                       Physical and Related Sciences    8,422  ±1,411
# 5                                          Psychology   16,023  ±2,067
# 6                                     Social Sciences   30,564  ±2,156
# 7                                         Engineering    9,195  ±1,385
# 8                           Multidisciplinary Studies    1,920    ±739
# 9              Science and Engineering Related Fields   17,106  ±1,869
# 10                                           Business   26,033  ±2,272
# 11                                          Education   15,395  ±1,876
# 13                           Literature and Languages   18,592  ±1,939
# ...

# %%
por12 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor12.csv')
por12 = por12.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por12 = por12.dropna()
por12
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  218,014  ±6,916
# 2               Computers, Mathematics and Statistics    7,338  ±1,231
# 3           Biological, Agricultural, and Environm...   13,716  ±1,935
# 4                       Physical and Related Sciences    8,422  ±1,411
# 5                                          Psychology   16,023  ±2,067
# 6                                     Social Sciences   30,564  ±2,156
# 7                                         Engineering    9,195  ±1,385
# 8                           Multidisciplinary Studies    1,920    ±739
# 9              Science and Engineering Related Fields   17,106  ±1,869
# 10                                           Business   26,033  ±2,272
# 11                                          Education   15,395  ±1,876
# 13                           Literature and Languages   18,592  ±1,939
# ...

# %%
por11 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor11.csv')
por11 = por11.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por11 = por11.dropna()
por11
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  201,944  ±6,753
# 2               Computers, Mathematics and Statistics    5,454  ±1,245
# 3           Biological, Agricultural, and Environm...   15,732  ±2,151
# 4                       Physical and Related Sciences    7,980  ±1,349
# 5                                          Psychology   13,063  ±1,479
# 6                                     Social Sciences   24,240  ±2,505
# 7                                         Engineering   10,113  ±1,590
# 8                           Multidisciplinary Studies    2,932    ±734
# 9              Science and Engineering Related Fields   14,950  ±1,553
# 10                                           Business   24,204  ±2,590
# 11                                          Education   12,726  ±1,754
# 13                           Literature and Languages   19,209  ±2,053
# ...

# %%
por10 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachpor10.csv')
por10 = por10.rename(columns = {'Label (Grouping)': 'Label', 'Portland city, Oregon!!Estimate':'Estimate','Portland city, Oregon!!Margin of Error':'ME'})
por10 = por10.dropna()
por10
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:  193,552  ±6,678
# 2               Computers, Mathematics and Statistics    6,937  ±1,483
# 3           Biological, Agricultural, and Environm...   15,732  ±2,167
# 4                       Physical and Related Sciences    7,449  ±1,158
# 5                                          Psychology   12,148  ±1,824
# 6                                     Social Sciences   23,398  ±2,319
# 7                                         Engineering    8,425  ±1,367
# 8                           Multidisciplinary Studies    1,871    ±804
# 9              Science and Engineering Related Fields   15,350  ±1,988
# 10                                           Business   21,414  ±1,837
# 11                                          Education   12,603  ±1,496
# 13                           Literature and Languages   14,582  ±1,446
# ...

# %%
van15 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan15.csv')
van15 = van15.rename(columns = {'Label (Grouping)':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van15 = van15.dropna()
van15
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:   35,205  ±2,969
# 2               Computers, Mathematics and Statistics      872    ±310
# 3           Biological, Agricultural, and Environm...    2,527    ±905
# 4                       Physical and Related Sciences    1,267    ±607
# 5                                          Psychology    2,094    ±701
# 6                                     Social Sciences    3,662    ±922
# 7                                         Engineering    3,214    ±937
# 8                           Multidisciplinary Studies      251    ±217
# 9              Science and Engineering Related Fields    3,369  ±1,007
# 10                                           Business    5,271  ±1,036
# 11                                          Education    3,232    ±890
# 13                           Literature and Languages    1,687    ±809
# ...

# %%
van14 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan14.csv')
van14 = van14.rename(columns = {'Label (Grouping)':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van14 = van14.dropna()
van14
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:   31,111  ±2,874
# 2               Computers, Mathematics and Statistics    1,256    ±436
# 3           Biological, Agricultural, and Environm...    2,177    ±744
# 4                       Physical and Related Sciences    1,081    ±463
# 5                                          Psychology    1,684    ±515
# 6                                     Social Sciences    3,138    ±799
# 7                                         Engineering    1,980    ±609
# 8                           Multidisciplinary Studies       86    ±102
# 9              Science and Engineering Related Fields    2,483    ±700
# 10                                           Business    5,481  ±1,170
# 11                                          Education    3,856    ±991
# 13                           Literature and Languages    1,808    ±516
# ...

# %%
van13 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan13.csv')
van13 = van13.rename(columns = {'Label (Grouping)':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van13 = van13.dropna()
van13
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:   32,292  ±2,540
# 2               Computers, Mathematics and Statistics    1,425    ±669
# 3           Biological, Agricultural, and Environm...    2,064    ±810
# 4                       Physical and Related Sciences    1,477    ±696
# 5                                          Psychology    1,711    ±535
# 6                                     Social Sciences    2,543    ±724
# 7                                         Engineering    2,039    ±594
# 8                           Multidisciplinary Studies      270    ±223
# 9              Science and Engineering Related Fields    2,792    ±844
# 10                                           Business    4,875  ±1,031
# 11                                          Education    3,826    ±824
# 13                           Literature and Languages    1,186    ±471
# ...

# %%
van12 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan12.csv')
van12 = van12.rename(columns = {'Label (Grouping)':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van12 = van12.dropna()
van12
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:   31,661  ±3,024
# 2               Computers, Mathematics and Statistics    1,084    ±503
# 3           Biological, Agricultural, and Environm...    1,623    ±636
# 4                       Physical and Related Sciences      944    ±407
# 5                                          Psychology    1,413    ±469
# 6                                     Social Sciences    2,323    ±666
# 7                                         Engineering    3,130    ±751
# 8                           Multidisciplinary Studies      121    ±150
# 9              Science and Engineering Related Fields    2,750    ±784
# 10                                           Business    4,964  ±1,004
# 11                                          Education    3,930    ±891
# 13                           Literature and Languages    2,051    ±529
# ...

# %%
van11 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan11.csv')
van11 = van11.rename(columns = {'Label (Grouping)':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van11 = van11.dropna()
van11
# Out:
#                                                 Label Estimate      ME
# 0                                              Total:   31,624  ±3,163
# 2               Computers, Mathematics and Statistics    1,780    ±899
# 3           Biological, Agricultural, and Environm...    2,058    ±763
# 4                       Physical and Related Sciences    2,006    ±984
# 5                                          Psychology    1,549    ±593
# 6                                     Social Sciences    3,582    ±981
# 7                                         Engineering    1,754    ±603
# 8                           Multidisciplinary Studies      199    ±173
# 9              Science and Engineering Related Fields    3,187    ±811
# 10                                           Business    5,343  ±1,164
# 11                                          Education    4,617  ±1,114
# 13                           Literature and Languages      986    ±565
# ...

# %%
van10 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/totbachvan10.csv')
van10 = van10.rename(columns = {'Label (Grouping':'Label','Vancouver city, Washington!!Estimate':'Estimate','Vancouver city, Washington!!Margin of Error':'ME'})
van10 = van10.dropna()
van10
# Out:
#                                      Label (Grouping) Estimate      ME
# 0                                              Total:   25,131  ±2,632
# 2               Computers, Mathematics and Statistics      899    ±417
# 3           Biological, Agricultural, and Environm...    1,278    ±478
# 4                       Physical and Related Sciences      690    ±409
# 5                                          Psychology    1,123    ±497
# 6                                     Social Sciences    2,739    ±831
# 7                                         Engineering    1,887    ±640
# 8                           Multidisciplinary Studies      115    ±134
# 9              Science and Engineering Related Fields    2,137    ±654
# 10                                           Business    4,220    ±982
# 11                                          Education    2,898    ±736
# 13                           Literature and Languages    1,281    ±435
# ...

# %%
van19t =van19['Estimate'].iloc[0]
van19t
# Out:
# '43,850'

# %%
van18t =van18['Estimate'].iloc[0]
van17t =van17['Estimate'].iloc[0]
van16t =van16['Estimate'].iloc[0]
van15t =van15['Estimate'].iloc[0]
van14t =van14['Estimate'].iloc[0]
van13t =van13['Estimate'].iloc[0]
van12t =van12['Estimate'].iloc[0]
van11t =van11['Estimate'].iloc[0]
van10t =van10['Estimate'].iloc[0]

# %%
por19t =por19['Estimate'].iloc[0]
por18t =por18['Estimate'].iloc[0]
por17t =por17['Estimate'].iloc[0]
por16t =por16['Estimate'].iloc[0]
por15t =por15['Estimate'].iloc[0]
por14t =por14['Estimate'].iloc[0]
por13t =por13['Estimate'].iloc[0]
por12t =por12['Estimate'].iloc[0]
por11t =por11['Estimate'].iloc[0]
por10t =por10['Estimate'].iloc[0]

# %%
por10t
# Out:
# '193,552'

# %%
porbach = pd.DataFrame(np.array([por10t,por11t,por12t,por13t,por14t,por15t,por16t,por17t,por18t,por19t]),
                   columns=['Total Bach Degree'])
porbach['Total Bach Degree'] = porbach['Total Bach Degree'].str.replace(',','')
porbach['Total Bach Degree'] = porbach['Total Bach Degree'].astype(int)
porbach
# Out:
#    Total Bach Degree
# 0             193552
# 1             201944
# 2             218014
# 3             228288
# 4             228443
# 5             250228
# 6             259541
# 7             266000
# 8             273786
# 9             286626

# %%
vanbach = pd.DataFrame(np.array([van10t,van11t,van12t,van13t,van14t,van15t,van16t,van17t,van18t,van19t]),
                   columns=['Total Bach Degree'])
vanbach['Total Bach Degree'] = vanbach['Total Bach Degree'].str.replace(',','')
vanbach['Total Bach Degree'] = vanbach['Total Bach Degree'].astype(int)
vanbach
# Out:
#    Total Bach Degree
# 0              25131
# 1              31624
# 2              31661
# 3              32292
# 4              31111
# 5              35205
# 6              35774
# 7              37759
# 8              43670
# 9              43850

# %%
vanbachgr = ((vanbach['Total Bach Degree'].iloc[9]-vanbach['Total Bach Degree'].iloc[0])/vanbach['Total Bach Degree'].iloc[0])*100
vanbachgr = float(vanbachgr)
vanbachgr = f"{vanbachgr:.2f}"
vanbachgr
# Out:
# '74.49'

# %%
porbachgr = ((porbach['Total Bach Degree'].iloc[9]-porbach['Total Bach Degree'].iloc[0])/porbach['Total Bach Degree'].iloc[0])*100
porbachgr = float(porbachgr)
porbachgr = f"{porbachgr:.2f}"
porbachgr
# Out:
# '48.09'

# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
vanbach.index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# %%
plt.plot(vanbach)

# %%
porbach.index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# %%
plt.plot(porbach)

# %%
EDjoin = pd.merge(
    vanbach,
    porbach,
    how="inner",
    on=porbach.index,
    left_index=False,
    right_index=False,
    sort=True,
    suffixes=("_x", "_y"),
    copy=True,
    indicator=False,
    validate=None)
print(EDjoin)
# Out:
#    key_0  Total Bach Degree_x  Total Bach Degree_y
# 0   2010                25131               193552
# 1   2011                31624               201944
# 2   2012                31661               218014
# 3   2013                32292               228288
# 4   2014                31111               228443
# 5   2015                35205               250228
# 6   2016                35774               259541
# 7   2017                37759               266000
# 8   2018                43670               273786
# 9   2019                43850               286626

# %%
EDjoin.columns
# Out:
# Index(['key_0', 'Total Bach Degree_x', 'Total Bach Degree_y'], dtype='object')

# %%
EDjoin = EDjoin.rename(columns = {'key_0':'Year','Total Bach Degree_x':'VanTotBach','Total Bach Degree_y':'PorTotBach'})

# %%
EDjoin.index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# %%
plt.plot(EDjoin['Year'],(EDjoin['VanTotBach']))
plt.plot(EDjoin['Year'],(EDjoin['PorTotBach']))
plt.title('Total Bachelors Degrees')
plt.xlabel = ('Year')
plt.xlabel = ('Total Bachelors Degree')
plt.show()

# %%
plt.plot(EDjoin['Year'],(EDjoin['VanTotBach']),label = 'Vancouver')
plt.plot(EDjoin['Year'],(EDjoin['PorTotBach']),label = 'Portland')
plt.title('Total Bachelors Degrees')
plt.legend()
plt.xlabel = ('Year')
plt.ylabel = ('Total')
plt.show()
print('The growth in total Bachelors Degrees in Vancouver between 2010 and 2019 is',vanbachgr,'%.')
print('The growth in total Bachelors Degrees in Portland between 2010 and 2019 is',porbachgr,'%.')
# Out:
# The growth in total Bachelors Degrees in Vancouver between 2010 and 2019 is 74.49 %.
# The growth in total Bachelors Degrees in Portland between 2010 and 2019 is 48.09 %.

# %%
PorHI19 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI19.csv')
PorHI18 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI18.csv')
PorHI17 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI17.csv')
PorHI16 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI16.csv')
PorHI15 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI15.csv')
PorHI14 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI14.csv')
PorHI13 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI13.csv')
PorHI12 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI12.csv')
PorHI11 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI11.csv')
PorHI10 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/PORHI10.csv')

# %%
PorHI19 = PorHI19.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI18 = PorHI18.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI17 = PorHI17.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI16 = PorHI16.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI15 = PorHI15.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI14 = PorHI14.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI13 = PorHI13.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI12 = PorHI12.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI11 = PorHI11.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})
PorHI10 = PorHI10.rename(columns = {'Label (Grouping)':'Income Group','Portland city, Oregon!!Estimate':'PopulationEst','Portland city, Oregon!!Margin of Error':'ME'})

# %%
VanHI19 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI19.csv')
VanHI18 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI18.csv')
VanHI17 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI17.csv')
VanHI16 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI16.csv')
VanHI15 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI15.csv')
VanHI14 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI14.csv')
VanHI13 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI13.csv')
VanHI12 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI12.csv')
VanHI11 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI11.csv')
VanHI10 = pd.read_csv('/Users/ianmonroe/Desktop/PDXVANCENS/VANHI10.csv')

# %%
VanHI19 = VanHI19.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI18 = VanHI18.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI17 = VanHI17.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI16 = VanHI16.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI15 = VanHI15.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI14 = VanHI14.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI13 = VanHI13.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI12 = VanHI12.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI11 = VanHI11.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})
VanHI10 = VanHI10.rename(columns = {'Label (Grouping)':'Income Group','Vancouver city, Washington!!Estimate':'PopulationEst','Vancouver city, Washington!!Margin of Error':'ME'})

# %%
VanHI10
# Out:
#                 Income Group PopulationEst      ME
# 0                     Total:        65,143  ±1,106
# 1          Less than $10,000         4,267    ±491
# 2         $10,000 to $14,999         3,348    ±360
# 3         $15,000 to $19,999         3,465    ±424
# 4         $20,000 to $24,999         3,872    ±379
# 5         $25,000 to $29,999         3,769    ±434
# 6         $30,000 to $34,999         3,864    ±456
# 7         $35,000 to $39,999         3,829    ±434
# 8         $40,000 to $44,999         3,716    ±415
# 9         $45,000 to $49,999         3,162    ±320
# 10        $50,000 to $59,999         6,611    ±493
# 11        $60,000 to $74,999         7,409    ±537
# 12        $75,000 to $99,999         8,182    ±791
# 13      $100,000 to $124,999         4,574    ±451
# 14      $125,000 to $149,999         1,920    ±291
# 15      $150,000 to $199,999         1,915    ±268
# 16          $200,000 or more         1,240    ±219

# %%
VanHI19['PopulationEst'] = VanHI19['PopulationEst'].str.replace(u',','')
VanHI19['PopulationEst'] = VanHI19['PopulationEst'].astype(int)
VanLoHI19 = sum(VanHI19['PopulationEst'][1:12])
VanLorate19 = (VanLoHI19/VanHI19['PopulationEst'][0])*100
VanLorate19 = float(VanLorate19)
VanLorate19 = f"{VanLorate19:.3f}"
VanUHI19 = sum(VanHI19['PopulationEst'][12:16])
VanUrate19 = (VanUHI19/VanHI19['PopulationEst'][0])*100
VanUrate19 = float(VanUrate19)
VanUrate19 = f"{VanUrate19:.3f}"
VanWHI19 = (VanHI19['PopulationEst'].iloc[16])
VanWrate19 = (VanWHI19/VanHI19['PopulationEst'][0])*100
VanWrate19 = float(VanWrate19)
VanWrate19 = f"{VanWrate19:.3f}"

VanHI18['PopulationEst'] = VanHI18['PopulationEst'].str.replace(u',','')
VanHI18['PopulationEst'] = VanHI18['PopulationEst'].astype(int)
VanLoHI18 = sum(VanHI18['PopulationEst'][1:12])
VanLorate18 = (VanLoHI18/VanHI18['PopulationEst'][0])*100
VanLorate18 = float(VanLorate18)
VanLorate18 = f"{VanLorate18:.3f}"
VanUHI18 = sum(VanHI18['PopulationEst'][12:16])
VanUrate18 = (VanUHI18/VanHI18['PopulationEst'][0])*100
VanUrate18 = float(VanUrate18)
VanUrate18 = f"{VanUrate18:.3f}"
VanWHI18 = (VanHI18['PopulationEst'].iloc[16])
VanWrate18 = (VanWHI18/VanHI18['PopulationEst'][0])*100
VanWrate18 = float(VanWrate18)
VanWrate18 = f"{VanWrate18:.3f}"

VanHI17['PopulationEst'] = VanHI17['PopulationEst'].str.replace(u',','')
VanHI17['PopulationEst'] = VanHI17['PopulationEst'].astype(int)
VanLoHI17 = sum(VanHI17['PopulationEst'][1:12])
VanLorate17 = (VanLoHI17/VanHI17['PopulationEst'][0])*100
VanLorate17 = float(VanLorate17)
VanLorate17 = f"{VanLorate17:.3f}"
VanUHI17 = sum(VanHI17['PopulationEst'][12:16])
VanUrate17 = (VanUHI17/VanHI17['PopulationEst'][0])*100
VanUrate17 = float(VanUrate17)
VanUrate17 = f"{VanUrate17:.3f}"
VanWHI17 = (VanHI17['PopulationEst'].iloc[16])
VanWrate17 = (VanWHI17/PorHI17['PopulationEst'][0])*100
VanWrate17 = float(VanWrate17)
VanWrate17 = f"{VanWrate17:.3f}"

VanHI16['PopulationEst'] = VanHI16['PopulationEst'].str.replace(u',','')
VanHI16['PopulationEst'] = VanHI16['PopulationEst'].astype(int)
VanLoHI16 = sum(VanHI16['PopulationEst'][1:12])
VanLorate16 = (VanLoHI16/VanHI16['PopulationEst'][0])*100
VanLorate16 = float(VanLorate16)
VanLorate16 = f"{VanLorate16:.3f}"
VanUHI16 = sum(VanHI16['PopulationEst'][12:16])
VanUrate16 = (VanUHI16/VanHI16['PopulationEst'][0])*100
VanUrate16 = float(VanUrate16)
VanUrate16 = f"{VanUrate16:.3f}"
VanWHI16 = (VanHI16['PopulationEst'].iloc[16])
VanWrate16 = (VanWHI16/VanHI16['PopulationEst'][0])*100
VanWrate16 = float(VanWrate16)
VanWrate16 = f"{VanWrate16:.3f}"

VanHI15['PopulationEst'] = VanHI15['PopulationEst'].str.replace(u',','')
VanHI15['PopulationEst'] = VanHI15['PopulationEst'].astype(int)
VanLoHI15 = sum(VanHI15['PopulationEst'][1:12])
VanLorate15 = (VanLoHI15/VanHI15['PopulationEst'][0])*100
VanLorate15 = float(VanLorate15)
VanLorate15 = f"{VanLorate15:.3f}"
VanUHI15 = sum(VanHI15['PopulationEst'][12:16])
VanUrate15 = (VanUHI15/VanHI15['PopulationEst'][0])*100
VanUrate15 = float(VanUrate15)
VanUrate15 = f"{VanUrate15:.3f}"
VanWHI15 = (VanHI15['PopulationEst'].iloc[16])
VanWrate15 = (VanWHI15/VanHI15['PopulationEst'][0])*100
VanWrate15 = float(VanWrate15)
VanWrate15 = f"{VanWrate15:.3f}"

VanHI14['PopulationEst'] = VanHI14['PopulationEst'].str.replace(u',','')
VanHI14['PopulationEst'] = VanHI14['PopulationEst'].astype(int)
VanLoHI14 = sum(VanHI14['PopulationEst'][1:12])
VanLorate14 = (VanLoHI14/VanHI14['PopulationEst'][0])*100
VanLorate14 = float(VanLorate14)
VanLorate14 = f"{VanLorate14:.3f}"
VanUHI14 = sum(VanHI14['PopulationEst'][12:16])
VanUrate14 = (VanUHI14/VanHI14['PopulationEst'][0])*100
VanUrate14 = float(VanUrate14)
VanUrate14 = f"{VanUrate14:.3f}"
VanWHI14 = (VanHI14['PopulationEst'].iloc[16])
VanWrate14 = (VanWHI14/PorHI14['PopulationEst'][0])*100
VanWrate14 = float(VanWrate14)
VanWrate14 = f"{VanWrate14:.3f}"

VanHI13['PopulationEst'] = VanHI13['PopulationEst'].str.replace(u',','')
VanHI13['PopulationEst'] = VanHI13['PopulationEst'].astype(int)
VanLoHI13 = sum(VanHI13['PopulationEst'][1:12])
VanLorate13 = (VanLoHI13/VanHI13['PopulationEst'][0])*100
VanLorate13 = float(VanLorate13)
VanLorate13 = f"{VanLorate13:.3f}"
VanUHI13 = sum(VanHI13['PopulationEst'][12:16])
VanUrate13 = (VanUHI13/VanHI13['PopulationEst'][0])*100
VanUrate13 = float(VanUrate13)
VanUrate13 = f"{VanUrate13:.3f}"
VanWHI13 = (VanHI13['PopulationEst'].iloc[16])
VanWrate13 = (VanWHI13/VanHI13['PopulationEst'][0])*100
VanWrate13 = float(VanWrate13)
VanWrate13 = f"{VanWrate13:.3f}"

VanHI12['PopulationEst'] = VanHI12['PopulationEst'].str.replace(u',','')
VanHI12['PopulationEst'] = VanHI12['PopulationEst'].astype(int)
VanLoHI12 = sum(VanHI12['PopulationEst'][1:12])
VanLorate12 = (VanLoHI12/VanHI12['PopulationEst'][0])*100
VanLorate12 = float(VanLorate12)
VanLorate12 = f"{VanLorate12:.3f}"
VanUHI12 = sum(VanHI12['PopulationEst'][12:16])
VanUrate12 = (VanUHI12/VanHI12['PopulationEst'][0])*100
VanUrate12 = float(VanUrate12)
VanUrate12 = f"{VanUrate12:.3f}"
VanWHI12 = (VanHI12['PopulationEst'].iloc[16])
VanWrate12 = (VanWHI12/VanHI12['PopulationEst'][0])*100
VanWrate12 = float(VanWrate12)
VanWrate12 = f"{VanWrate12:.3f}"

VanHI11['PopulationEst'] = VanHI11['PopulationEst'].str.replace(u',','')
VanHI11['PopulationEst'] = VanHI11['PopulationEst'].astype(int)
VanLoHI11 = sum(VanHI11['PopulationEst'][1:12])
VanLorate11 = (VanLoHI11/VanHI11['PopulationEst'][0])*100
VanLorate11 = float(VanLorate11)
VanLorate11 = f"{VanLorate11:.3f}"
VanUHI11 = sum(VanHI11['PopulationEst'][12:16])
VanUrate11 = (VanUHI11/VanHI11['PopulationEst'][0])*100
VanUrate11 = float(VanUrate11)
VanUrate11 = f"{VanUrate11:.3f}"
VanWHI11 = (VanHI11['PopulationEst'].iloc[16])
VanWrate11 = (VanWHI11/PorHI11['PopulationEst'][0])*100
VanWrate11 = float(VanWrate11)
VanWrate11 = f"{VanWrate11:.3f}"

VanHI10['PopulationEst'] = VanHI10['PopulationEst'].str.replace(u',','')
VanHI10['PopulationEst'] = VanHI10['PopulationEst'].astype(int)
VanLoHI10 = sum(VanHI10['PopulationEst'][1:12])
VanLorate10 = (VanLoHI10/VanHI10['PopulationEst'][0])*100
VanLorate10 = float(VanLorate10)
VanLorate10 = f"{VanLorate10:.3f}"
VanUHI10 = sum(VanHI10['PopulationEst'][12:16])
VanUrate10 = (VanUHI10/VanHI10['PopulationEst'][0])*100
VanUrate10 = float(VanUrate10)
VanUrate10 = f"{VanUrate10:.3f}"
VanWHI10 = (VanHI10['PopulationEst'].iloc[16])
VanWrate10 = (VanWHI10/VanHI10['PopulationEst'][0])*100
VanWrate10 = float(VanWrate10)
VanWrate10 = f"{VanWrate10:.3f}"

# %%
PorHI19['PopulationEst'] = PorHI19['PopulationEst'].str.replace(u',','')
PorHI19['PopulationEst'] = PorHI19['PopulationEst'].astype(int)
PorLoHI19 = sum(PorHI19['PopulationEst'][1:12])
PorLorate19 = (PorLoHI19/PorHI19['PopulationEst'][0])*100
PorLorate19 = float(PorLorate19)
PorLorate19 = f"{PorLorate19:.3f}"
PorUHI19 = sum(PorHI19['PopulationEst'][12:16])
PorUrate19 = (PorUHI19/PorHI19['PopulationEst'][0])*100
PorUrate19 = float(PorUrate19)
PorUrate19 = f"{PorUrate19:.3f}"
PorWHI19 = (PorHI19['PopulationEst'].iloc[16])
PorWrate19 = (PorWHI19/PorHI19['PopulationEst'][0])*100
PorWrate19 = float(PorWrate19)
PorWrate19 = f"{PorWrate19:.3f}"

PorHI18['PopulationEst'] = PorHI18['PopulationEst'].str.replace(u',','')
PorHI18['PopulationEst'] = PorHI18['PopulationEst'].astype(int)
PorLoHI18 = sum(PorHI18['PopulationEst'][1:12])
PorLorate18 = (PorLoHI18/PorHI18['PopulationEst'][0])*100
PorLorate18 = float(PorLorate18)
PorLorate18 = f"{PorLorate18:.3f}"
PorUHI18 = sum(PorHI18['PopulationEst'][12:16])
PorUrate18 = (PorUHI18/PorHI18['PopulationEst'][0])*100
PorUrate18 = float(PorUrate18)
PorUrate18 = f"{PorUrate18:.3f}"
PorWHI18 = (PorHI18['PopulationEst'].iloc[16])
PorWrate18 = (PorWHI18/PorHI18['PopulationEst'][0])*100
PorWrate18 = float(PorWrate18)
PorWrate18 = f"{PorWrate18:.3f}"

PorHI17['PopulationEst'] = PorHI17['PopulationEst'].str.replace(u',','')
PorHI17['PopulationEst'] = PorHI17['PopulationEst'].astype(int)
PorLoHI17 = sum(PorHI17['PopulationEst'][1:12])
PorLorate17 = (PorLoHI17/PorHI17['PopulationEst'][0])*100
PorLorate17 = float(PorLorate17)
PorLorate17 = f"{PorLorate17:.3f}"
PorUHI17 = sum(PorHI17['PopulationEst'][12:16])
PorUrate17 = (PorUHI17/PorHI17['PopulationEst'][0])*100
PorUrate17 = float(PorUrate17)
PorUrate17 = f"{PorUrate17:.3f}"
PorWHI17 = (PorHI17['PopulationEst'].iloc[16])
PorWrate17 = (PorWHI17/PorHI17['PopulationEst'][0])*100
PorWrate17 = float(PorWrate17)
PorWrate17 = f"{PorWrate17:.3f}"

PorHI16['PopulationEst'] = PorHI16['PopulationEst'].str.replace(u',','')
PorHI16['PopulationEst'] = PorHI16['PopulationEst'].astype(int)
PorLoHI16 = sum(PorHI16['PopulationEst'][1:12])
PorLorate16 = (PorLoHI16/PorHI16['PopulationEst'][0])*100
PorLorate16 = float(PorLorate16)
PorLorate16 = f"{PorLorate16:.3f}"
PorUHI16 = sum(PorHI16['PopulationEst'][12:16])
PorUrate16 = (PorUHI16/PorHI16['PopulationEst'][0])*100
PorUrate16 = float(PorUrate16)
PorUrate16 = f"{PorUrate16:.3f}"
PorWHI16 = (PorHI16['PopulationEst'].iloc[16])
PorWrate16 = (PorWHI16/PorHI16['PopulationEst'][0])*100
PorWrate16 = float(PorWrate16)
PorWrate16 = f"{PorWrate16:.3f}"

PorHI15['PopulationEst'] = PorHI15['PopulationEst'].str.replace(u',','')
PorHI15['PopulationEst'] = PorHI15['PopulationEst'].astype(int)
PorLoHI15 = sum(PorHI15['PopulationEst'][1:12])
PorLorate15 = (PorLoHI15/PorHI15['PopulationEst'][0])*100
PorLorate15 = float(PorLorate15)
PorLorate15 = f"{PorLorate15:.3f}"
PorUHI15 = sum(PorHI15['PopulationEst'][12:16])
PorUrate15 = (PorUHI15/PorHI15['PopulationEst'][0])*100
PorUrate15 = float(PorUrate15)
PorUrate15 = f"{PorUrate15:.3f}"
PorWHI15 = (PorHI15['PopulationEst'].iloc[16])
PorWrate15 = (PorWHI15/PorHI15['PopulationEst'][0])*100
PorWrate15 = float(PorWrate15)
PorWrate15 = f"{PorWrate15:.3f}"

PorHI14['PopulationEst'] = PorHI14['PopulationEst'].str.replace(u',','')
PorHI14['PopulationEst'] = PorHI14['PopulationEst'].astype(int)
PorLoHI14 = sum(PorHI14['PopulationEst'][1:12])
PorLorate14 = (PorLoHI14/PorHI14['PopulationEst'][0])*100
PorLorate14 = float(PorLorate14)
PorLorate14 = f"{PorLorate14:.3f}"
PorUHI14 = sum(PorHI14['PopulationEst'][12:16])
PorUrate14 = (PorUHI14/PorHI14['PopulationEst'][0])*100
PorUrate14 = float(PorUrate14)
PorUrate14 = f"{PorUrate14:.3f}"
PorWHI14 = (PorHI14['PopulationEst'].iloc[16])
PorWrate14 = (PorWHI14/PorHI14['PopulationEst'][0])*100
PorWrate14 = float(PorWrate14)
PorWrate14 = f"{PorWrate14:.3f}"

PorHI13['PopulationEst'] = PorHI13['PopulationEst'].str.replace(u',','')
PorHI13['PopulationEst'] = PorHI13['PopulationEst'].astype(int)
PorLoHI13 = sum(PorHI13['PopulationEst'][1:12])
PorLorate13 = (PorLoHI13/PorHI13['PopulationEst'][0])*100
PorLorate13 = float(PorLorate13)
PorLorate13 = f"{PorLorate13:.3f}"
PorUHI13 = sum(PorHI13['PopulationEst'][12:16])
PorUrate13 = (PorUHI13/PorHI13['PopulationEst'][0])*100
PorUrate13 = float(PorUrate13)
PorUrate13 = f"{PorUrate13:.3f}"
PorWHI13 = (PorHI13['PopulationEst'].iloc[16])
PorWrate13 = (PorWHI13/PorHI13['PopulationEst'][0])*100
PorWrate13 = float(PorWrate13)
PorWrate13 = f"{PorWrate13:.3f}"

PorHI12['PopulationEst'] = PorHI12['PopulationEst'].str.replace(u',','')
PorHI12['PopulationEst'] = PorHI12['PopulationEst'].astype(int)
PorLoHI12 = sum(PorHI12['PopulationEst'][1:12])
PorLorate12 = (PorLoHI12/PorHI12['PopulationEst'][0])*100
PorLorate12 = float(PorLorate12)
PorLorate12 = f"{PorLorate12:.3f}"
PorUHI12 = sum(PorHI12['PopulationEst'][12:16])
PorUrate12 = (PorUHI12/PorHI12['PopulationEst'][0])*100
PorUrate12 = float(PorUrate12)
PorUrate12 = f"{PorUrate12:.3f}"
PorWHI12 = (PorHI12['PopulationEst'].iloc[16])
PorWrate12 = (PorWHI12/PorHI12['PopulationEst'][0])*100
PorWrate12 = float(PorWrate12)
PorWrate12 = f"{PorWrate12:.3f}"

PorHI11['PopulationEst'] = PorHI11['PopulationEst'].str.replace(u',','')
PorHI11['PopulationEst'] = PorHI11['PopulationEst'].astype(int)
PorLoHI11 = sum(PorHI11['PopulationEst'][1:12])
PorLorate11 = (PorLoHI11/PorHI11['PopulationEst'][0])*100
PorLorate11 = float(PorLorate11)
PorLorate11 = f"{PorLorate11:.3f}"
PorUHI11 = sum(PorHI11['PopulationEst'][12:16])
PorUrate11 = (PorUHI11/PorHI11['PopulationEst'][0])*100
PorUrate11 = float(PorUrate11)
PorUrate11 = f"{PorUrate11:.3f}"
PorWHI11 = (PorHI11['PopulationEst'].iloc[16])
PorWrate11 = (PorWHI11/PorHI11['PopulationEst'][0])*100
PorWrate11 = float(PorWrate11)
PorWrate11 = f"{PorWrate11:.3f}"

PorHI10['PopulationEst'] = PorHI10['PopulationEst'].str.replace(u',','')
PorHI10['PopulationEst'] = PorHI10['PopulationEst'].astype(int)
PorLoHI10 = sum(PorHI10['PopulationEst'][1:12])
PorLorate10 = (PorLoHI10/PorHI10['PopulationEst'][0])*100
PorLorate10 = float(PorLorate10)
PorLorate10 = f"{PorLorate10:.3f}"
PorUHI10 = sum(PorHI10['PopulationEst'][12:16])
PorUrate10 = (PorUHI10/PorHI10['PopulationEst'][0])*100
PorUrate10 = float(PorUrate10)
PorUrate10 = f"{PorUrate10:.3f}"
PorWHI10 = (PorHI10['PopulationEst'].iloc[16])
PorWrate10 = (PorWHI10/PorHI10['PopulationEst'][0])*100
PorWrate10 = float(PorWrate10)
PorWrate10 = f"{PorWrate10:.3f}"

# %%
PorLoIndex = {PorLorate10: 2010, PorLorate11: 2011,
           PorLorate12: 2012,PorLorate13: 2013, PorLorate14: 2014,
           PorLorate15: 2015,PorLorate16: 2016, PorLorate17: 2017,
           PorLorate18: 2018,PorLorate19:2019}
PorUIndex = {PorUrate10: 2010, PorUrate11: 2011,
           PorUrate12: 2012,PorUrate13: 2013, PorUrate14: 2014,
           PorUrate15: 2015,PorUrate16: 2016, PorUrate17: 2017,
           PorUrate18: 2018,PorUrate19:2019}
PorWIndex = {PorWrate10: 2010, PorWrate11: 2011,
           PorWrate12: 2012,PorWrate13: 2013, PorWrate14: 2014,
           PorWrate15: 2015,PorWrate16: 2016, PorWrate17: 2017,
           PorWrate18: 2018,PorWrate19:2019}

# %%
VanLoIndex = {VanLorate10: 2010, VanLorate11: 2011,
           VanLorate12: 2012,VanLorate13: 2013, VanLorate14: 2014,
           VanLorate15: 2015,VanLorate16: 2016, VanLorate17: 2017,
           VanLorate18: 2018,VanLorate19:2019}
VanUIndex = {VanUrate10: 2010, VanUrate11: 2011,
           VanUrate12: 2012,VanUrate13: 2013, VanUrate14: 2014,
           VanUrate15: 2015,VanUrate16: 2016, VanUrate17: 2017,
           VanUrate18: 2018,VanUrate19:2019}
VanWIndex = {VanWrate10: 2010, VanWrate11: 2011,
           VanWrate12: 2012,VanWrate13: 2013, VanWrate14: 2014,
           VanWrate15: 2015,VanWrate16: 2016, VanWrate17: 2017,
           VanWrate18: 2018,VanWrate19:2019}

# %%
PorLoHI = pd.DataFrame(np.array([PorLoHI10,PorLoHI11,PorLoHI12,PorLoHI13,PorLoHI14,PorLoHI15,PorLoHI16,PorLoHI17,PorLoHI18,PorLoHI19]),
                      columns = ['Low to Median Income'],index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])

PorLoHI['Percentage'] = PorLoIndex
PorLoHI
# Out:
#       Low to Median Income Percentage
# 2010                170148     69.504
# 2011                169621     68.475
# 2012                166172     66.857
# 2013                163091     65.202
# 2014                162879     64.587
# 2015                160656     63.209
# 2016                155470     60.628
# 2017                152536     58.454
# 2018                147131     55.641
# 2019                140876     52.425

# %%
VanLoHI = pd.DataFrame(np.array([VanLoHI10,VanLoHI11,VanLoHI12,VanLoHI13,VanLoHI14,VanLoHI15,VanLoHI16,VanLoHI17,VanLoHI18,VanLoHI19]),
                      columns = ['Low to Median Income'],index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])

VanLoHI['Percentage'] = VanLoIndex
VanLoHI
# Out:
#       Low to Median Income Percentage
# 2010                 47312     72.628
# 2011                 47491     71.884
# 2012                 47246     71.635
# 2013                 46958     71.358
# 2014                 45894     69.890
# 2015                 46281     69.682
# 2016                 45843     68.075
# 2017                 44238     64.905
# 2018                 45071     62.953
# 2019                 43748     60.335

# %%
PorUHI = pd.DataFrame(np.array([PorUHI10,PorUHI11,PorUHI12,PorUHI13,PorUHI14,PorUHI15,PorUHI16,PorUHI17,PorUHI18,PorUHI19]),
                      columns = ['Median to High Income'],index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])
PorUHI['Percentage'] = PorUIndex
PorUHI
# Out:
#       Median to High Income Percentage
# 2010                  16591     25.469
# 2011                  17245     26.103
# 2012                  17380     26.352
# 2013                  17106     25.995
# 2014                  17905     27.267
# 2015                  78912     27.418
# 2016                  19327     28.700
# 2017                  21342     31.313
# 2018                  23355     32.621
# 2019                  25274     34.857

# %%
VanUHI = pd.DataFrame(np.array([VanUHI10,VanUHI11,VanUHI12,VanUHI13,VanUHI14,VanUHI15,VanUHI16,VanUHI17,VanUHI18,VanUHI19]),
                      columns = ['Median to High Income'],index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])
VanUHI['Percentage'] = VanUIndex
VanUHI
# Out:
#       Median to High Income Percentage
# 2010                  16591     25.469
# 2011                  17245     26.103
# 2012                  17380     26.352
# 2013                  17106     25.995
# 2014                  17905     27.267
# 2015                  18210     27.418
# 2016                  19327     28.700
# 2017                  21342     31.313
# 2018                  23355     32.621
# 2019                  25274     34.857

# %%
PorWHI = pd.DataFrame(np.array([PorWHI10,PorWHI11,PorWHI12,PorWHI13,PorWHI14,PorWHI15,PorWHI16,PorWHI17,PorWHI18,PorWHI19]),
                      columns = ['High Income'],index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])
PorWHI['Percentage'] = PorWIndex
PorWHI
# Out:
#       High Income Percentage
# 2010         9993      4.082
# 2011        10665      4.305
# 2012        11499      4.626
# 2013        12369      4.945
# 2014        13397      5.312
# 2015        14599      5.744
# 2016        17085      6.663
# 2017        19750      7.569
# 2018        22505      8.511
# 2019        26212      9.754

# %%
VanWHI = pd.DataFrame(np.array([VanWHI10,VanWHI11,VanWHI12,VanWHI13,VanWHI14,VanWHI15,VanWHI16,VanWHI17,VanWHI18,VanWHI19]),
                      columns = ['High Income'],index = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019])
VanWHI['Percentage'] = VanWIndex
VanWHI
# Out:
#       High Income Percentage
# 2010         1240      1.904
# 2011         1330      0.537
# 2012         1328      2.014
# 2013         1742      2.647
# 2014         1867      0.740
# 2015         1926      2.900
# 2016         2172      3.225
# 2017         2578      0.988
# 2018         3169      4.426
# 2019         3486      4.808

# %%
PorHIjoin = pd.merge(
    PorLoHI,
    PorUHI,
    how="inner",
    on=PorLoHI.index,
    left_index=False,
    right_index=False,
    sort=True,
    suffixes=("_x", "_y"),
    copy=True,
    indicator=False,
    validate=None)
print(PorHIjoin)
# Out:
#    key_0  Low to Median Income Percentage_x  Median to High Income  \
# 0   2010                170148       69.504                  64662
# 1   2011                169621       68.475                  67425
# 2   2012                166172       66.857                  70878
# 3   2013                163091       65.202                  74673
# 4   2014                162879       64.587                  75909
# 5   2015                160656       63.209                  78912
# 6   2016                155470       60.628                  83877
# 7   2017                152536       58.454                  88663
# 8   2018                147131       55.641                  94792
# 9   2019                140876       52.425                 101630
#
#   Percentage_y
# 0       26.414
# 1       27.219
# 2       28.517
# 3       29.853
# 4       30.101
# 5       31.047
# 6       32.709
# 7       33.977
# 8       35.848
# 9       37.820

# %%
VanHIjoin = pd.merge(
    VanLoHI,
    VanUHI,
    how="inner",
    on=VanLoHI.index,
    left_index=False,
    right_index=False,
    sort=True,
    suffixes=("_x", "_y"),
    copy=True,
    indicator=False,
    validate=None)
print(PorHIjoin)
# Out:
#    key_0  Low to Median Income Percentage_x  Median to High Income  \
# 0   2010                170148       69.504                  64662
# 1   2011                169621       68.475                  67425
# 2   2012                166172       66.857                  70878
# 3   2013                163091       65.202                  74673
# 4   2014                162879       64.587                  75909
# 5   2015                160656       63.209                  78912
# 6   2016                155470       60.628                  83877
# 7   2017                152536       58.454                  88663
# 8   2018                147131       55.641                  94792
# 9   2019                140876       52.425                 101630
#
#   Percentage_y
# 0       26.414
# 1       27.219
# 2       28.517
# 3       29.853
# 4       30.101
# 5       31.047
# 6       32.709
# 7       33.977
# 8       35.848
# 9       37.820

# %%
VanHIjoin.columns
# Out:
# Index(['key_0', 'Low to Median Income', 'Percentage_x',
#        'Median to High Income', 'Percentage_y'],
#       dtype='object')

# %%
PorHIjoin = PorHIjoin.merge(PorWHI, left_on='key_0',right_index=True, suffixes=(False, False))

# %%
VanHIjoin = VanHIjoin.merge(VanWHI, left_on='key_0',right_index=True, suffixes=(False, False))

# %%
PorHIjoin = PorHIjoin.rename(columns = {'key_0':'Year','Percentage_x':'Percentage LM','Percentage_y':'Percentage MH','Percentage':'Percentage H'})
PorHIjoin
# Out:
#    Year  Low to Median Income Percentage LM  Median to High Income  \
# 0  2010                170148        69.504                  64662
# 1  2011                169621        68.475                  67425
# 2  2012                166172        66.857                  70878
# 3  2013                163091        65.202                  74673
# 4  2014                162879        64.587                  75909
# 5  2015                160656        63.209                  78912
# 6  2016                155470        60.628                  83877
# 7  2017                152536        58.454                  88663
# 8  2018                147131        55.641                  94792
# 9  2019                140876        52.425                 101630
#
#   Percentage MH  High Income Percentage H
# 0        26.414         9993        4.082
# 1        27.219        10665        4.305
# 2        28.517        11499        4.626
# 3        29.853        12369        4.945
# ...

# %%
VanHIjoin = VanHIjoin.rename(columns = {'key_0':'Year','Percentage_x':'Percentage LM','Percentage_y':'Percentage MH','Percentage':'Percentage H'})
VanHIjoin
# Out:
#    Year  Low to Median Income Percentage LM  Median to High Income  \
# 0  2010                 47312        72.628                  16591
# 1  2011                 47491        71.884                  17245
# 2  2012                 47246        71.635                  17380
# 3  2013                 46958        71.358                  17106
# 4  2014                 45894        69.890                  17905
# 5  2015                 46281        69.682                  18210
# 6  2016                 45843        68.075                  19327
# 7  2017                 44238        64.905                  21342
# 8  2018                 45071        62.953                  23355
# 9  2019                 43748        60.335                  25274
#
#   Percentage MH  High Income Percentage H
# 0        25.469         1240        1.904
# 1        26.103         1330        0.537
# 2        26.352         1328        2.014
# 3        25.995         1742        2.647
# ...

# %%
PorLMgr = ((PorHIjoin['Low to Median Income'][9] - PorHIjoin['Low to Median Income'][0])/PorHIjoin['Low to Median Income'][0])*100
PorLMgr
# Out:
# -17.203846063427132

# %%
VanLMgr = ((VanHIjoin['Low to Median Income'][9] - VanHIjoin['Low to Median Income'][0])/VanHIjoin['Low to Median Income'][0])*100
VanLMgr
# Out:
# -7.532972607372337

# %%
plt.plot(PorHIjoin['Year'],(PorHIjoin['Low to Median Income']),label = 'Low to Median Income')
plt.plot(PorHIjoin['Year'],(PorHIjoin['Median to High Income']),label = 'Median to High Income')
plt.plot(PorHIjoin['Year'],(PorHIjoin['High Income']),label = 'High Income')
plt.title('Portland Household Income Growth')
plt.legend()
ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel = ('Year')
plt.ylabel = ('Population')
plt.show()
print ('The percentage of Household Incomes in Portland below $74,999 has fallen from',PorHIjoin['Percentage LM'][0],'% in 2010 to',PorHIjoin['Percentage LM'][9],'$ in 2019.')
print ('The percentage of Household Incomes in Portland between $75,000 and $199,999 has increased from',PorHIjoin['Percentage MH'][0],'% in 2010 to',PorHIjoin['Percentage MH'][9],'$ in 2019.')
print ('The percentage of Household Incomes in Portland above $200,000 has increased from',PorHIjoin['Percentage H'][0],'% in 2010 to',PorHIjoin['Percentage H'][9],'$ in 2019.')
# Out:
# <ipython-input-192-bbb64a43732b>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)
# The percentage of Household Incomes in Portland below $74,999 has fallen from 69.504 % in 2010 to 52.425 $ in 2019.
# The percentage of Household Incomes in Portland between $75,000 and $199,999 has increased from 26.414 % in 2010 to 37.820 $ in 2019.
# The percentage of Household Incomes in Portland above $200,000 has increased from 4.082 % in 2010 to 9.754 $ in 2019.

# %%
plt.plot(VanHIjoin['Year'],(VanHIjoin['Low to Median Income']),label = 'Low to Median Income')
plt.plot(VanHIjoin['Year'],(VanHIjoin['Median to High Income']),label = 'Median to High Income')
plt.plot(VanHIjoin['Year'],(VanHIjoin['High Income']),label = 'High Income')
plt.title('Vancouver Household Income Growth')
plt.legend()
ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel = ('Year')
plt.ylabel = ('Population')
plt.show()
print ('The percentage of Household Incomes in Vancouver below $74,999 has fallen from',VanHIjoin['Percentage LM'][0],'% in 2010 to',VanHIjoin['Percentage LM'][9],'$ in 2019.')
print ('The percentage of Household Incomes in Vancouver between $75,000 and $199,999 has increased from',VanHIjoin['Percentage MH'][0],'% in 2010 to',VanHIjoin['Percentage MH'][9],'$ in 2019.')
print ('The percentage of Household Incomes in Vancouver above $200,000 has increased from',VanHIjoin['Percentage H'][0],'% in 2010 to',VanHIjoin['Percentage H'][9],'$ in 2019.')
# Out:
# <ipython-input-193-b4ffe90a7c34>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)
# The percentage of Household Incomes in Vancouver below $74,999 has fallen from 72.628 % in 2010 to 60.335 $ in 2019.
# The percentage of Household Incomes in Vancouver between $75,000 and $199,999 has increased from 25.469 % in 2010 to 34.857 $ in 2019.
# The percentage of Household Incomes in Vancouver above $200,000 has increased from 1.904 % in 2010 to 4.808 $ in 2019.
